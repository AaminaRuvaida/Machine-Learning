# %% [markdown]
# # Unsupervised learning

# %% [markdown]
# # Kmeans Clustering

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv('Mall_customers.csv')
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x=dataset.iloc[:,3:]
x.tail(10)
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 190                 103                      23
# 191                 103                      69
# 192                 113                       8
# 193                 113                      91
# 194                 120                      16
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83

# %%
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++')
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss,marker='x',color='green')
plt.title("The Elbow Method")
plt.xlabel("Number of Cluster")
plt.ylabel("WCSS")
plt.show()

# %%
# Fitting the kmeans in the datasets

kmeans=KMeans(n_clusters=5,init='k-means++')
y_kmeans=kmeans.fit_predict(x)
print(y_kmeans)
# Out:
# [1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1 4 1
#  4 1 4 1 4 1 2 1 4 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 0 3 0 2 0 3 0 3 0 2 0 3 0 3 0 3 0 3 0 2 0 3 0 3 0
#  3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3 0 3
#  0 3 0 3 0 3 0 3 0 3 0 3 0 3 0]

# %%
kmeans.labels_
# Out:
# array([1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4,
#        1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 2,
#        1, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 3, 0, 2, 0, 3, 0, 3, 0,
#        2, 0, 3, 0, 3, 0, 3, 0, 3, 0, 2, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0,
#        3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0,
#        3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0,
#        3, 0])

# %%
kmeans.cluster_centers_
# Out:
# array([[86.53846154, 82.12820513],
#        [26.30434783, 20.91304348],
#        [55.2962963 , 49.51851852],
#        [88.2       , 17.11428571],
#        [25.72727273, 79.36363636]])

# %%
x[y_kmeans==0]
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 123                  69                      91
# 125                  70                      77
# 127                  71                      95
# 129                  71                      75
# 131                  71                      75
# 133                  72                      71
# 135                  73                      88
# 137                  73                      73
# 139                  74                      72
# 141                  75                      93
# 143                  76                      87
# 145                  77                      97
# 147                  77                      74
# 149                  78                      90
# 151                  78                      88
# 153                  78                      76
# 155                  78                      89
# 157                  78                      78
# 159                  78                      73
# ...

# %%
x[y_kmeans==1]
# Out:
#     Annual Income (k$)  Spending Score (1-100)
# 0                   15                      39
# 2                   16                       6
# 4                   17                      40
# 6                   18                       6
# 8                   19                       3
# 10                  19                      14
# 12                  20                      15
# 14                  20                      13
# 16                  21                      35
# 18                  23                      29
# 20                  24                      35
# 22                  25                       5
# 24                  28                      14
# 26                  28                      32
# 28                  29                      31
# 30                  30                       4
# 32                  33                       4
# 34                  33                      14
# 36                  34                      17
# ...

# %%
x[y_kmeans==2]
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 43                   39                      61
# 46                   40                      55
# 47                   40                      47
# 48                   40                      42
# 49                   40                      42
# ..                  ...                     ...
# 121                  67                      40
# 122                  69                      58
# 126                  71                      35
# 132                  72                      34
# 142                  76                      40
#
# [81 rows x 2 columns]

# %%
x[y_kmeans==3]
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 124                  70                      29
# 128                  71                      11
# 130                  71                       9
# 134                  73                       5
# 136                  73                       7
# 138                  74                      10
# 140                  75                       5
# 144                  77                      12
# 146                  77                      36
# 148                  78                      22
# 150                  78                      17
# 152                  78                      20
# 154                  78                      16
# 156                  78                       1
# 158                  78                       1
# 160                  79                      35
# 162                  81                       5
# 164                  85                      26
# 166                  86                      20
# ...

# %%
dd=pd.DataFrame(data=x[y_kmeans==2])
dd
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 43                   39                      61
# 46                   40                      55
# 47                   40                      47
# 48                   40                      42
# 49                   40                      42
# ..                  ...                     ...
# 121                  67                      40
# 122                  69                      58
# 126                  71                      35
# 132                  72                      34
# 142                  76                      40
#
# [81 rows x 2 columns]

# %%
dd.to_csv("Mall_group2.csv")

# %%
# Saving the model in a local file system

import pickle
filename='Mall_kmeans.pickle'
pickle.dump(kmeans,open(filename, 'wb'))

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
ds=pd.DataFrame(data=dataset)
ds
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
ds['Group Cluster']=pd.DataFrame(data=kmeans.labels_)
ds
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Group Cluster
# 0                1
# 1                4
# 2                1
# ...

# %%
ds.to_csv('Mall_customers_clusterfile.csv',index=False)

# %%
myds=pd.read_csv('Mall_customers_clusterfile.csv')
myds
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Group Cluster
# 0                1
# 1                4
# 2                1
# ...

# %%
plt.figure(figsize=(8,8))
plt.scatter(x[y_kmeans==0]['Annual Income (k$)'],x[y_kmeans==0]['Spending Score (1-100)'],s=100,color='green',label='Cluster 1')
plt.scatter(x[y_kmeans==1]['Annual Income (k$)'],x[y_kmeans==1]['Spending Score (1-100)'],s=100,color='red',label='Cluster 2')
plt.scatter(x[y_kmeans==2]['Annual Income (k$)'],x[y_kmeans==2]['Spending Score (1-100)'],s=100,color='yellow',label='Cluster 3')
plt.scatter(x[y_kmeans==3]['Annual Income (k$)'],x[y_kmeans==3]['Spending Score (1-100)'],s=100,color='purple',label='Cluster 4')
plt.scatter(x[y_kmeans==4]['Annual Income (k$)'],x[y_kmeans==4]['Spending Score (1-100)'],s=100,color='Blue',label='Cluster 5')

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=100,color='cyan',label='Centroid')

plt.title("Cutomer Groups")
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()

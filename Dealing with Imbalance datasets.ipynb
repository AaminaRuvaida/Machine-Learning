# %% [markdown]
# # How to deal Imbalance dataset?

# %%
import pandas as pd

# %%
df=pd.read_csv('Diabetes_predict.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
df['Outcome'].value_counts()
# Out:
# 0    1316
# 1     684
# Name: Outcome, dtype: int64

# %%
x=df.drop('Outcome',axis=1)

# %%
x
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age
# 0                        0.127   47
# ...

# %%
y=df.Outcome
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1995    0
# 1996    1
# 1997    0
# 1998    1
# 1999    0
# Name: Outcome, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)

# %%
x_train.shape
# Out:
# (1400, 8)

# %%
x_test.shape
# Out:
# (600, 8)

# %%
y_train.shape
# Out:
# (1400,)

# %%
y_test.shape
# Out:
# (600,)

# %% [markdown]
# # Upsampling

# %%
from sklearn.utils import resample

# %%
x=pd.concat([x_train,y_train],axis=1)

# %%
x
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 954             0      145              0              0        0  44.2
# 1429            2      108             62             32       56  25.2
# 444             4      117             62             12        0  29.7
# 852             1      109             60              8      182  25.4
# 1903            7       83             78             26       71  29.3
# ...           ...      ...            ...            ...      ...   ...
# 1589            6      139             84             37        0  50.7
# 810             1      130             70             13      105  25.9
# 1775            1      107             50             19        0  28.3
# 528             0      117             66             31      188  30.8
# 1787            4      118             70              0        0  44.5
#
#       DiabetesPedigreeFunction  Age  Outcome
# 954                      0.630   31        1
# ...

# %%
not_dia=x[x.Outcome==0]

# %%
not_dia
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1429            2      108             62             32       56  25.2
# 852             1      109             60              8      182  25.4
# 1903            7       83             78             26       71  29.3
# 1601            3       99             62             19       74  21.8
# 1524            0      124             56             13      105  21.8
# ...           ...      ...            ...            ...      ...   ...
# 504             3       96             78             39        0  37.3
# 810             1      130             70             13      105  25.9
# 1775            1      107             50             19        0  28.3
# 528             0      117             66             31      188  30.8
# 1787            4      118             70              0        0  44.5
#
#       DiabetesPedigreeFunction  Age  Outcome
# 1429                     0.128   21        0
# ...

# %%
diabetes=x[x.Outcome==1]

# %%
diabetes
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 954             0      145              0              0        0  44.2
# 444             4      117             62             12        0  29.7
# 695             7      142             90             24      480  30.4
# 972             6        0             68             41        0  39.0
# 1794           10      115              0              0        0   0.0
# ...           ...      ...            ...            ...      ...   ...
# 84              5      137            108              0        0  48.8
# 230             4      142             86              0        0  44.0
# 64              7      114             66              0        0  32.8
# 826             1      125             50             40      167  33.3
# 1589            6      139             84             37        0  50.7
#
#       DiabetesPedigreeFunction  Age  Outcome
# 954                      0.630   31        1
# ...

# %%
dia_upsampled=resample(diabetes,
                      replace=True,
                      n_samples=len(not_dia),
                      random_state=27)

# %%
dia_upsampled
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 175             8      179             72             42      130  32.7
# 451             2      134             70              0        0  28.9
# 284             2      108             80              0        0  27.0
# 280             0      146             70              0        0  37.9
# 1061            4      183              0              0        0  28.4
# ...           ...      ...            ...            ...      ...   ...
# 1364            8      196             76             29      280  37.5
# 1667            0      138             60             35      167  34.6
# 827            13      129              0             30        0  39.9
# 539             3      129             92             49      155  36.4
# 1257            1      122             90             51      220  49.7
#
#       DiabetesPedigreeFunction  Age  Outcome
# 175                      0.719   36        1
# ...

# %%
unsampled=pd.concat([not_dia, dia_upsampled])

# %%
unsampled
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1429            2      108             62             32       56  25.2
# 852             1      109             60              8      182  25.4
# 1903            7       83             78             26       71  29.3
# 1601            3       99             62             19       74  21.8
# 1524            0      124             56             13      105  21.8
# ...           ...      ...            ...            ...      ...   ...
# 1364            8      196             76             29      280  37.5
# 1667            0      138             60             35      167  34.6
# 827            13      129              0             30        0  39.9
# 539             3      129             92             49      155  36.4
# 1257            1      122             90             51      220  49.7
#
#       DiabetesPedigreeFunction  Age  Outcome
# 1429                     0.128   21        0
# ...

# %%
unsampled.Outcome.value_counts()
# Out:
# 0    933
# 1    933
# Name: Outcome, dtype: int64

# %% [markdown]
# # Downsampling

# %%
not_dia_downsampled=resample(not_dia,
                            replace=False,
                            n_samples=len(diabetes),
                            random_state=27)

# %%
not_dia_downsampled
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 991             1       77             56             30       56  33.3
# 1098            4      128             70              0        0  34.3
# 721             1      114             66             36      200  38.1
# 15              2       81             72             15       76  30.1
# 526             1       97             64             19       82  18.2
# ...           ...      ...            ...            ...      ...   ...
# 180             6       87             80              0        0  23.2
# 491             2       89             90             30        0  33.5
# 1029            3      111             58             31       44  29.5
# 1879            0      146             82              0        0  40.5
# 126             3      120             70             30      135  42.9
#
#       DiabetesPedigreeFunction  Age  Outcome
# 991                      1.251   24        0
# ...

# %%
downsampled=pd.concat([not_dia_downsampled, diabetes])

# %%
downsampled.Outcome.value_counts()
# Out:
# 0    467
# 1    467
# Name: Outcome, dtype: int64
